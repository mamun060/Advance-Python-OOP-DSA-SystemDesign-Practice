# %%
import pandas as pd
import numpy as np

# Load the dataset
# Ensure 'score.csv' is in the exact same directory as this notebook file
try:
    df = pd.read_csv('Score.csv')
    print("✓ Dataset successfully loaded!")
except FileNotFoundError:
    print("✗ Error: 'Score.csv' not found in this directory. Please check the file path.")
# Out:
# ✗ Error: 'Score.csv' not found in this directory. Please check the file path.

# %%
# View the shape of the dataset (Rows, Columns)
print(f"Dataset Shape: {df.shape[0]} rows, {df.shape[1]} columns\n")

# Peek at the top 5 rows
print("--- FIRST 5 ROWS ---")
display(df.head())

# Inspect column names and data types
print("\n--- DATA TYPES & COLUMNS ---")
df.info()

# %%
print("--- MISSING VALUES PER COLUMN ---")
missing_values = df.isnull().sum()
display(missing_values[missing_values > 0] if missing_values.sum() > 0 else "No missing values found! The data is clean.")

# %%
print("--- DESCRIPTIVE STATISTICS ---")
# Generates count, mean, standard deviation, min, max, and percentiles for numeric columns
df.describe()
# Out:
# --- DESCRIPTIVE STATISTICS ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 print("--- DESCRIPTIVE STATISTICS ---")
#       2 # Generates count, mean, standard deviation, min, max, and percentiles for numeric columns
# ----> 3 df.describe()
#
# NameError: name 'df' is not defined
